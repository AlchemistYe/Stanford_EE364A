# %%
import numpy as np
import cvxpy as cvx
import pandas as pd
import holoviews as hv
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# # Q1 - Maximum likelihood estimation of an increasing nonnegative signal

# %%
# create problem data 
N = 100; 

# create an increasing input signal
xtrue = np.zeros((N,1))
xtrue[1:40] = 0.1
xtrue[50] = 2
xtrue[70:80] = 0.15;
xtrue[80] = 1
xtrue = np.cumsum(xtrue)

# pass the increasing input through a moving-average filter 
# and add Gaussian noise
h = np.array([1, -0.85 ,0.7 ,-0.3])
k = h.shape[0]
yhat = np.convolve(h,xtrue)
y = yhat[:-3]\
    + np.array([-0.43,-1.7,0.13,0.29,-1.1,1.2,1.2,-0.038,0.33,0.17,-0.19,0.73,-0.59,2.2,-0.14,0.11,1.1,0.059,-0.096,-0.83,0.29,-1.3,0.71,1.6,-0.69,0.86,1.3,-1.6,-1.4,0.57,-0.4,0.69,0.82,0.71,1.3,0.67,1.2,-1.2,-0.02,-0.16,-1.6,0.26,-1.1,1.4,-0.81,0.53,0.22,-0.92,-2.2,-0.059,-1,0.61,0.51,1.7,0.59,-0.64,0.38,-1,-0.02,-0.048,4.3e-05,-0.32,1.1,-1.9,0.43,0.9,0.73,0.58,0.04,0.68,0.57,-0.26,-0.38,-0.3,-1.5,-0.23,0.12,0.31,1.4,-0.35,0.62,0.8,0.94,-0.99,0.21,0.24,-1,-0.74,1.1,-0.13,0.39,0.088,-0.64,-0.56,0.44,-0.95,0.78,0.57,-0.82,-0.27])

# %% [markdown]
# Find the maximum likelihood estimate , and plot it, along with the true signal. Also find and plot the maximum likelihood estimate  not taking into account the signal nonnegativity and monotonicity.
#
# Hint. The function conv (convolution) is overloaded to work with CVX.

# %%
x = cvx.Variable((100),nonneg = True)
z = y[:,None] - cvx.conv(h,x)[:-3]
constraints = [cvx.diff(x) >= 0]
nll = cvx.Minimize(cvx.sum_squares(z))
prob=cvx.Problem(nll,constraints=constraints)
prob.solve()

# with monotinicity and nonegativiness
hv.Curve(x.value,label="x_hat").options(width=900) * hv.Curve(xtrue,label="x_true").options(width=900)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\86159\OneDrive\Standford_CVX101-master\hws\HW6\HW6.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/86159/OneDrive/Standford_CVX101-master/hws/HW6/HW6.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> x = cvx.Variable((100),nonneg = True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/86159/OneDrive/Standford_CVX101-master/hws/HW6/HW6.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> z = y[:,None] - cvx.conv(h,x)[:-3]
#       <a href='vscode-notebook-cell:/c%3A/Users/86159/OneDrive/Standford_CVX101-master/hws/HW6/HW6.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> constraints = [cvx.diff(x) >= 0]
#       <a href='vscode-notebook-cell:/c%3A/Users/86159/OneDrive/Standford_CVX101-master/hws/HW6/HW6.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> nll = cvx.Minimize(cvx.sum_squares(z))
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:745, in Expression.__array_ufunc__(self, ufunc, method, *args, **kwargs)
#     741     ufunc_handler = __BINARY_EXPRESSION_UFUNCS__[ufunc]
#     742     if kwargs == {} and \
#     743             len(args) == 2 and \
#     744             args[1] is self:
# --> 745         return ufunc_handler(self, args[0])
#     746 except KeyError:
#     747     pass
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:72, in <lambda>(self, a)
#      56 __STAR_MATMUL_WARNING__ = """
#      57 This use of ``*`` has resulted in matrix multiplication.
#      58 Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#    (...)
#      62 This code path has been hit %s times so far.
#      63 """
#      65 __NUMPY_UFUNC_ERROR__ = """
#      66 You're calling a NumPy function on a CVXPY expression. This is prone to causing
#      67 errors or code that doesn't behave as expected. Consider using one of the
#      68 functions documented here: https://www.cvxpy.org/tutorial/functions/index.html
#      69 """
#      70 __BINARY_EXPRESSION_UFUNCS__ = {
#      71         np.add: lambda self, a: self.__radd__(a),
# ---> 72         np.subtract: lambda self, a: self.__rsub__(a),
#      73         np.multiply: lambda self, a: self.__rmul__(a),
#      74         np.divide: lambda self, a: self.__rdiv__(a),
#      75         np.matmul: lambda self, a: self.__rmatmul__(a),
#      76         np.power: lambda self, a: self.__rpow__(a),
#      77         np.left_shift: lambda self, a: self.__rlshift__(a),
#      78         np.right_shift: lambda self, a: self.__rrshift__(a),
#      79         np.equal: lambda self, a: self.__eq__(a),
#      80         # <= and >= are backwards because this is only called for code of the
#      81         # form ndarray <= Expression
#      82         np.less_equal: lambda self, a: self.__ge__(a),
#      83         np.greater_equal: lambda self, a: self.__le__(a),
#      84         np.less: lambda self, a: self.__gt__(a),
#      85         np.greater: lambda self, a: self.__lt__(a),
#      86 }
#      89 class Expression(u.Canonical):
#      90     """A mathematical expression in a convex optimization problem.
#      91
#      92     Overloads many operators to allow for convenient creation of compound
#      93     expressions (e.g., the sum of two expressions) and constraints.
#      94     """
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:50, in _cast_other.<locals>.cast_op(self, other)
#      47 """A wrapped binary operator that can handle non-Expression arguments.
#      48 """
#      49 other = self.cast_to_const(other)
# ---> 50 return binary_op(self, other)
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:581, in Expression.__rsub__(self, other)
#     577 @_cast_other
#     578 def __rsub__(self, other: "Expression") -> "Expression":
#     579     """Expression : The difference of two expressions.
#     580     """
# --> 581     return other - self
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:50, in _cast_other.<locals>.cast_op(self, other)
#      47 """A wrapped binary operator that can handle non-Expression arguments.
#      48 """
#      49 other = self.cast_to_const(other)
# ---> 50 return binary_op(self, other)
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:575, in Expression.__sub__(self, other)
#     571 @_cast_other
#     572 def __sub__(self, other: "Expression") -> "Expression":
#     573     """Expression : The difference of two expressions.
#     574     """
# --> 575     return self + -other
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:50, in _cast_other.<locals>.cast_op(self, other)
#      47 """A wrapped binary operator that can handle non-Expression arguments.
#      48 """
#      49 other = self.cast_to_const(other)
# ---> 50 return binary_op(self, other)
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:561, in Expression.__add__(self, other)
#     559     return self
#     560 self, other = self.broadcast(self, other)
# --> 561 return cvxtypes.add_expr()([self, other])
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:34, in AddExpression.__init__(self, arg_groups)
#      31 def __init__(self, arg_groups) -> None:
#      32     # For efficiency group args as sums.
#      33     self._arg_groups = arg_groups
# ---> 34     super(AddExpression, self).__init__(*arg_groups)
#      35     self.args = []
#      36     for group in arg_groups:
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\atoms\atom.py:51, in Atom.__init__(self, *args)
#      49 self.args = [Atom.cast_to_const(arg) for arg in args]
#      50 self.validate_arguments()
# ---> 51 self._shape = self.shape_from_args()
#      52 if len(self._shape) > 2:
#      53     raise ValueError("Atoms must be at most 2D.")
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:42, in AddExpression.shape_from_args(self)
#      39 def shape_from_args(self) -> Tuple[int, ...]:
#      40     """Returns the (row, col) shape of the expression.
#      41     """
# ---> 42     return u.shape.sum_shapes([arg.shape for arg in self.args])
#
# File d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\utilities\shape.py:50, in sum_shapes(shapes)
#      47 for t in shapes[1:]:
#      48     # Only allow broadcasting for 0D arrays or summation of scalars.
#      49     if shape != t and len(squeezed(shape)) != 0 and len(squeezed(t)) != 0:
# ---> 50         raise ValueError(
#      51             "Cannot broadcast dimensions " +
#      52             len(shapes)*" %s" % tuple(shapes))
#      54     longer = shape if len(shape) >= len(t) else t
#      55     shorter = shape if len(shape) < len(t) else t
#
# ValueError: Cannot broadcast dimensions  (100, 1) (100,)

# %%
x = cvx.Variable((100,))
z = y[:,None] - cvx.conv(h,x)[:-3]
constraints = []
nll = cvx.Minimize(cvx.sum_squares(z))
prob=cvx.Problem(nll,constraints=constraints)
prob.solve()

# without monotinicity and nonegativiness
hv.Curve(x.value,label="x_hat").options(width=900) * hv.Curve(xtrue,label="x_true").options(width=900)
# Out:
# :Overlay
#    .Curve.X_hat  :Curve   [x]   (y)
#    .Curve.X_true :Curve   [x]   (y)

# %% [markdown]
# # Q2 - Worst-case probability of loss

# %%
mu1 = 8
mu2 = 20
sigma1 = 6
sigma2 = 17.5
rho = -0.25
N = 100
R = np.linspace(-30,69,100)
R1,R2 = np.meshgrid(R,R)
tot_return_mask = R1+R2 <= 0

# %%
p1 = np.exp(-(R-mu1)**2/(2*sigma1**2))
p1 /= sum(p1)
p2 = np.exp(-(R-mu2)**2/(2*sigma2**2))
p2 /= sum(p2)
P = cvx.Variable((N,N), nonneg=True)
constraints = [
      P * np.ones((N,1)) == p1[:,None]
    , np.ones((1,N)) * P == p2[None,:]
    , (R-mu1) * P * (R-mu2) == rho*sigma1*sigma2
]
loss = cvx.Maximize(cvx.sum(cvx.multiply(P,tot_return_mask)))
prob = cvx.Problem(loss,constraints)
prob.solve()
# Out:
# d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 1 times so far.
#
#   warnings.warn(msg, UserWarning)
# d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 2 times so far.
#
#   warnings.warn(msg, UserWarning)
# d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 3 times so far.
#
#   warnings.warn(msg, UserWarning)
# d:\anaconda\envs\cvxpy\Lib\site-packages\cvxpy\expressions\expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 4 times so far.
#
#   warnings.warn(msg, UserWarning)
# 0.19723081094022166

# %%
 hv.Image(P.value[::-1]).options(width=500,height=500, tools=['hover'])
# Out:
# :Image   [x,y]   (z)
